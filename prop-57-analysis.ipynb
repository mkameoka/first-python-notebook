# %% [markdown]
# # Prop 57 Analysis
#
# By *Marcio Kameoka*
#
# Training exercise - Python for Journalists course.
#
# Following the exercise, I've noticed that actually some of the largest contributors end up not showing in our final lists. This is due to them being not actual persons, but institutions of some kind (like NEXT GEN, GOVERNOR BROWN OFFICE, or whatever).
#
# As Sandra Fish and I discussed in the [forum for Module 3](http://journalismcourses.org/mod/forum/discuss.php?d=76735#p239564), in cases where the 'contributor_firstname' is empty, apparently the filter discards the entire row. Is that correct?
#
# With some [help](http://journalismcourses.org/mod/forum/discuss.php?d=77125#p240085), I introduced code to add 'no_name' in the firstname field, and now the list seems complete. Please jump to line 31 to check.

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
props = pd.read_csv("http://first-python-notebook.readthedocs.io/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
contribs = pd.read_csv("D:\Documents\Trampo\Academic\Python\contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop = props[props.prop_name == "PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 35  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 36  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 37  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 38  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 39  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#     ccdc_prop_id                                          prop_name  \
# 35            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 36            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 37            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 38            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 39            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 35                417                 1385745
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 35 to 47
# Data columns (total 8 columns):
# ocd_prop_id               13 non-null object
# calaccess_prop_id         13 non-null int64
# ccdc_prop_id              13 non-null int64
# prop_name                 13 non-null object
# ccdc_committee_id         13 non-null int64
# calaccess_committee_id    13 non-null int64
# committee_name            13 non-null object
# committee_position        13 non-null object
# dtypes: int64(4), object(4)
# memory usage: 728.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
contribs.amount.sort_values(0)
# Out:
# 30172     -150000.00
# 56365      -27000.00
# 32332      -15000.00
# 56366       -9000.00
# 41977       -5000.00
# 39881       -2500.00
# 46886       -2450.00
# 45679       -1000.00
# 29071       -1000.00
# 47149       -1000.00
# 29303       -1000.00
# 30155        -900.00
# 45769        -900.00
# 40564        -500.00
# 43615        -500.00
# 45271        -500.00
# 47148        -500.00
# 46545        -450.00
# 43141        -300.00
# 42908        -250.00
# 53722        -250.00
# 41049        -250.00
# 46064        -109.34
# 46525        -100.00
# 30168        -100.00
# 43543        -100.00
# 44089        -100.00
# 48569        -100.00
# 46533        -100.00
# 30089        -100.00
#             ...
# 45516     2800000.00
# 45502     2880000.00
# 45472     2880000.00
# 54781     3000000.00
# 28734     3000000.00
# 49866     3000000.00
# 49977     3500000.00
# 54469     4000000.00
# 45521     4000000.00
# 49857     4000000.00
# 45487     4150000.00
# 45498     4150000.00
# ...

# %%
contribs.amount.sum()
# Out:
# 408980909.53999996

# %% [markdown]
# Is the value above correct? When adding the value in excel, I keep getting 396700839

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#    ccdc_prop_id                                          prop_name  \
# 0            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 1            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 2            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 3            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 4            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                417                 1385745
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 236
# Data columns (total 20 columns):
# ocd_prop_id                     237 non-null object
# calaccess_prop_id               237 non-null int64
# ccdc_prop_id                    237 non-null int64
# prop_name                       237 non-null object
# ccdc_committee_id               237 non-null int64
# calaccess_committee_id          237 non-null int64
# committee_name_x                237 non-null object
# committee_position              237 non-null object
# committee_name_y                237 non-null object
# calaccess_filing_id             237 non-null int64
# date_received                   237 non-null object
# contributor_lastname            237 non-null object
# contributor_firstname           117 non-null object
# contributor_city                237 non-null object
# contributor_state               237 non-null object
# contributor_zip                 237 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 20097369.73

# %%
merged.committee_position.value_counts()
# Out:
# OPPOSE     146
# SUPPORT     91
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 236
# Data columns (total 20 columns):
# ocd_prop_id                     91 non-null object
# calaccess_prop_id               91 non-null int64
# ccdc_prop_id                    91 non-null int64
# prop_name                       91 non-null object
# ccdc_committee_id               91 non-null int64
# calaccess_committee_id          91 non-null int64
# committee_name_x                91 non-null object
# committee_position              91 non-null object
# committee_name_y                91 non-null object
# calaccess_filing_id             91 non-null int64
# date_received                   91 non-null object
# contributor_lastname            91 non-null object
# contributor_firstname           24 non-null object
# contributor_city                91 non-null object
# contributor_state               91 non-null object
# contributor_zip                 91 non-null object
# ...

# %%
support.amount.sum()
# Out:
# 19307322.729999997

# %%
oppose.amount.sum()
# Out:
# 790047.0

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.96068903490287716

# %%
oppose.amount.sum() / merged.amount.sum()
# Out:
# 0.039310965097122688

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 211  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 17   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 16   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 8    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 10   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 43   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 216  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 0    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 5    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
oppose.sort_values("amount", ascending=False).head(10)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 182  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 204  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 165  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 176  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 64   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 199  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 194  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 180  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 189  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 195  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#      ccdc_prop_id                                          prop_name  \
# 182            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# ...

# %%
merged.groupby(["committee_name_x", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                      committee_name_x committee_position  \
# 10  YES ON PROP. 57, CALIFORNIANS AND GOVERNOR BRO...            SUPPORT
# 3        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))            SUPPORT
# 6   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...            SUPPORT
# 4   FWD.US (NONPROFIT 501(C)(4)) IN SUPPORT OF PRO...            SUPPORT
# 7   NO ON 57 - STOP EARLY RELEASE OF VIOLENT CRIMI...             OPPOSE
# 8   OPEN PHILANTHROPY ACTION FUND YES ON 57 (NONPR...            SUPPORT
# 1   CALIFORNIA STATEWIDE LAW ENFORCEMENT ASSOCIATI...            SUPPORT
# 5   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...            SUPPORT
# 0   CALIFORNIA CALLS ACTION FUND (NONPROFIT 501(C)...            SUPPORT
# 2   CIVIC PARTICIPATION ACTION FUND - YES ON 57 (N...            SUPPORT
# 9   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...            SUPPORT
#
#         amount
# 10  8097730.06
# 3   6140000.00
# 6   2110000.00
# 4   1000000.00
# ...

# %%
merged.fillna("no_name").groupby(["contributor_firstname","contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname                               contributor_lastname  \
# 143               no_name                             FUND FOR POLICY REFORM
# 147               no_name          GOVERNOR BROWN'S BALLOT MEASURE COMMITTEE
# 103                THOMAS                                             STEYER
# 144               no_name  FWD.US (NONPROFIT 501(C)(4)) IN SUPPORT OF PRO...
# 165               no_name  OPEN SOCIETY POLICY CENTER, INC. (NONPROFIT 50...
# 73                   MARK                                         ZUCKERBERG
# 122               no_name                        CALIFORNIA DEMOCRATIC PARTY
# 28                 DUSTIN                                          MOSKOVITZ
# 127               no_name  CALIFORNIA STATEWIDE LAW ENFORCEMENT ASSOCIATI...
# 162               no_name                                 NEXTGEN CALIFORNIA
# 164               no_name  OPEN PHILANTHROPY ACTION FUND, YES ON 57 (NONP...
# ...

# %%
top_supporters = support.fillna("no_name").groupby(["contributor_firstname","contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head(10)
# Out:
#    contributor_firstname                               contributor_lastname  \
# 36               no_name                             FUND FOR POLICY REFORM
# 38               no_name          GOVERNOR BROWN'S BALLOT MEASURE COMMITTEE
# 21                THOMAS                                             STEYER
# 45               no_name  OPEN SOCIETY POLICY CENTER, INC. (NONPROFIT 50...
# 37               no_name  FWD.US (NONPROFIT 501(C)(4)) IN SUPPORT OF PRO...
# 15                  MARK                                         ZUCKERBERG
# 25               no_name                        CALIFORNIA DEMOCRATIC PARTY
# 6                 DUSTIN                                          MOSKOVITZ
# 29               no_name  CALIFORNIA STATEWIDE LAW ENFORCEMENT ASSOCIATI...
# 43               no_name                                 NEXTGEN CALIFORNIA
#
#         amount
# 36  6140000.00
# 38  4138764.06
# 21  1750000.00
# 45  1000000.00
# 37  1000000.00
# 15  1000000.00
# 25   900000.00
# ...

# %%
top_supporters.amount.plot.bar()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)

# %%
top_supporters['contributor_fullname'] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.head()
# Out:
#    contributor_firstname                               contributor_lastname  \
# 36               no_name                             FUND FOR POLICY REFORM
# 38               no_name          GOVERNOR BROWN'S BALLOT MEASURE COMMITTEE
# 21                THOMAS                                             STEYER
# 45               no_name  OPEN SOCIETY POLICY CENTER, INC. (NONPROFIT 50...
# 37               no_name  FWD.US (NONPROFIT 501(C)(4)) IN SUPPORT OF PRO...
#
#         amount                               contributor_fullname
# 36  6140000.00                     no_name FUND FOR POLICY REFORM
# 38  4138764.06  no_name GOVERNOR BROWN'S BALLOT MEASURE COMMITTEE
# 21  1750000.00                                      THOMAS STEYER
# 45  1000000.00  no_name OPEN SOCIETY POLICY CENTER, INC. (NONP...
# 37  1000000.00  no_name FWD.US (NONPROFIT 501(C)(4)) IN SUPPOR...

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)

# %%
top_supporters.head(5).to_csv("top_supporters.csv")

# %%
def combine_names(row):
    if row.contributor_fullname.startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row.contributor_fullname

# %%
top_supporters['contributor_cleanname'] = top_supporters.apply(combine_names, axis=1)

# %%
top_supporters.groupby("contributor_cleanname").amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
# Out:
#                                contributor_cleanname      amount
# 5                     no_name FUND FOR POLICY REFORM  6140000.00
# 7  no_name GOVERNOR BROWN'S BALLOT MEASURE COMMITTEE  4138764.06
# 2                                      THOMAS STEYER  1750000.00
# 1                                    MARK ZUCKERBERG  1000000.00
# 6  no_name FWD.US (NONPROFIT 501(C)(4)) IN SUPPOR...  1000000.00
# 9  no_name OPEN SOCIETY POLICY CENTER, INC. (NONP...  1000000.00
# 3                no_name CALIFORNIA DEMOCRATIC PARTY   900000.00
# 0                                   DUSTIN MOSKOVITZ   600000.00
# 4  no_name CALIFORNIA STATEWIDE LAW ENFORCEMENT A...   498096.00
# 8                         no_name NEXTGEN CALIFORNIA   250000.00
